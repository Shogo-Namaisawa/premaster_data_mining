# %% [markdown]
# # 第三回 pythonの基礎(2)
#
# 記述統計と可視化の基礎が講義内容で、コーディングは基本的にpandasのことをしていたよ

# %% [markdown]
# ### 使うcsvの作成
# 長いから実行したら削除している
#
# ``` python
#
# csv_data = """user,class
#
# """
#
# myfile = open('data/user_class.csv', 'w')
# myfile.write(csv_data)
# myfile.close()
# ```
#
#
# ### 対象データ
# - user_class.csv
# - simple_score.csv
# - user_score
